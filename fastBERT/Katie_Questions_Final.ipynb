# %% [markdown]
# Installing transformers is the first step.

# %%
# !pip install transformers

# %%
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
from transformers import AutoConfig, AutoModel

name = 'bert-base-cased'

tokenizer = AutoTokenizer.from_pretrained(name,)

model = AutoModelForQuestionAnswering.from_pretrained(name)

nlp = pipeline('question-answering')

def answer_que(questt, anss):
    print(nlp({
    'question': questt,
    'context': anss
}))

# %%
answer_que('how big is the chicken', 'this chicken is very big')
# Out:
# {'score': 0.7397379875183105, 'start': 16, 'end': 24, 'answer': 'very big'}

# %%
from transformers import pipeline
from transformers import AutoConfig, AutoModel

# %% [markdown]
# Use a **cased** model to **make a difference between english and English** and evaluate said model

# %%
model = AutoModel.from_pretrained('bert-base-cased')
model.eval()

# %%
nlp = pipeline('question-answering')
nlp.model
# Out:
# DistilBertForQuestionAnswering(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %% [markdown]
# One question that gives us good results is the following

# %%
import os


directory = '/content/test/'

for filename in os.listdir(directory):
  with open(directory + filename) as infile:
    try:

      next(infile)

      data=infile.read().replace('\n', '')
      print('\nFilename: ' + filename)
      print(nlp({
    'question': 'What does the computer decide?',
    'context': data
}))

    except:
        print(filename + ' is throwing an error')


'''
some testing
from transformers import pipeline

qa_pipeline = pipeline(
    "question-answering",
    model="madlag/bert-base-uncased-squadv1-x2.44-f87.7-d26-hybrid-filled-v1",
    tokenizer="madlag/bert-base-uncased-squadv1-x2.44-f87.7-d26-hybrid-filled-v1"
)'''
# Out:
# Filename: 6.txt
# {'score': 0.4266800582408905, 'start': 6380, 'end': 6423, 'answer': "whether you're going to have the stones out"}
#
# Filename: 30.txt
# {'score': 0.28379008173942566, 'start': 8164, 'end': 8209, 'answer': 'randomised, my darling, to medical management'}
#
# Filename: 9.txt
# {'score': 0.40633878111839294, 'start': 2947, 'end': 3012, 'answer': 'whether to have an operation or whether to just keep an eye on it'}
#
# Filename: 28.txt
# {'score': 0.050219275057315826, 'start': 3438, 'end': 3450, 'answer': 'consent form'}
#
# Filename: 13.txt
# {'score': 0.11498253047466278, 'start': 7757, 'end': 7778, 'answer': 'give us your initials'}
#
# Filename: 2.txt
# {'score': 0.1330416202545166, 'start': 4159, 'end': 4205, 'answer': 'whether or not you are suffering with the pain'}
#
# Filename: 4.txt
# {'score': 0.2755652964115143, 'start': 12046, 'end': 12085, 'answer': 'you are allocated to medical management'}
#
# Filename: 11.txt
# {'score': 0.4266130030155182, 'start': 2939, 'end': 2974, 'answer': 'It just knows that this is a number'}
#
# Filename: 15.txt
# {'score': 0.8420314192771912, 'start': 12037, 'end': 12100, 'answer': 'whether you get to be in the medical management or the surgical'}
#
# Filename: 10.txt
# {'score': 0.04730847850441933, 'start': 3504, 'end': 3519, 'answer': 'generate a code'}
#
# Filename: 20.txt
# {'score': 0.15535001456737518, 'start': 1220, 'end': 1283, 'answer': "to see people who don't have an operation how they cope with it"}
#
# Filename: 0.txt
# {'score': 0.43920090794563293, 'start': 11937, 'end': 11986, 'answer': "whether you get the surgery, or whether you don't"}
#
# Filename: 14.txt
# {'score': 8.422441896982491e-05, 'start': 2358, 'end': 2409, 'answer': 'blindly allocating you either surgery or no surgery'}
#
# Filename: 18.txt
# {'score': 0.24652954936027527, 'start': 5080, 'end': 5102, 'answer': 'the stones will remain'}
#
# Filename: 29.txt
# {'score': 0.07291511446237564, 'start': 9422, 'end': 9440, 'answer': 'right out my hands'}
#
# Filename: 27.txt
# {'score': 0.7225884199142456, 'start': 5000, 'end': 5034, 'answer': 'whether you wish to do that or not'}
#
# Filename: 21.txt
# {'score': 0.042591579258441925, 'start': 4169, 'end': 4184, 'answer': 'a questionnaire'}
#
# Filename: 23.txt
# {'score': 0.38603049516677856, 'start': 6941, 'end': 6946, 'answer': '50:50'}
#
# Filename: 25.txt
# {'score': 0.22328822314739227, 'start': 1902, 'end': 1929, 'answer': 'they are randomly allocated'}
#
# Filename: 3.txt
# {'score': 0.8816128969192505, 'start': 8323, 'end': 8334, 'answer': 'R1 - Superb'}
#
# Filename: 19.txt
# {'score': 0.14934557676315308, 'start': 4925, 'end': 4985, 'answer': 'you may be randomised to surgery straightaway and happy days'}
#
# Filename: 8.txt
# {'score': 0.5686531662940979, 'start': 4717, 'end': 4782, 'answer': 'whether we just keep an eye on them or whether we operate on them'}
#
# Filename: 5.txt
# {'score': 0.5213849544525146, 'start': 3316, 'end': 3380, 'answer': 'whether you have an operation or whether you have a wait and see'}
#
# Filename: 26.txt
# {'score': 0.0009836667450144887, 'start': 1295, 'end': 1318, 'answer': 'Everything is voluntary'}
#
# Filename: 12.txt
# {'score': 0.6329827904701233, 'start': 6232, 'end': 6265, 'answer': 'if you want to go into it, or not'}
#
# Filename: 1.txt
# {'score': 0.029934344813227654, 'start': 7032, 'end': 7051, 'answer': "We'll turn this off"}
#
# Filename: 24.txt
# {'score': 0.28406548500061035, 'start': 15112, 'end': 15142, 'answer': 'I just want my gallbladder out'}
#
# Filename: 7.txt
# {'score': 0.07767932116985321, 'start': 5726, 'end': 5750, 'answer': "we'll put your name down"}
#
# Filename: 17.txt
# {'score': 0.05622516945004463, 'start': 13452, 'end': 13475, 'answer': 'Everything is consented'}
#
# Filename: 22.txt
# {'score': 0.22474659979343414, 'start': 9219, 'end': 9257, 'answer': "which arm of the study you're going in"}
#
# Filename: 16.txt
# {'score': 0.43970856070518494, 'start': 6041, 'end': 6044, 'answer': '10%'}

# %% [markdown]
# One question about randomisation that also does the job fairly well

# %%
import os
directory = '/content/test/'

for filename in os.listdir(directory):
  with open(directory + filename) as infile:
    try:

      next(infile)

      data=infile.read().replace('\n', '')
      print('\nFilename: ' + filename)
      print(nlp({
    'question': 'What are you randomised for?',
    'context': data
}))

    except:
        print(filename + ' is throwing an error')
# Out:
# Filename: 6.txt
# {'score': 0.42546188831329346, 'start': 9993, 'end': 10008, 'answer': 'show gallstones'}
#
# Filename: 30.txt
# {'score': 0.813377320766449, 'start': 8191, 'end': 8209, 'answer': 'medical management'}
#
# Filename: 9.txt
# {'score': 0.8999626636505127, 'start': 7130, 'end': 7140, 'answer': 'no surgery'}
#
# Filename: 28.txt
# {'score': 0.8951448202133179, 'start': 1428, 'end': 1435, 'answer': 'surgery'}
#
# Filename: 13.txt
# {'score': 0.9406484365463257, 'start': 4072, 'end': 4079, 'answer': 'surgery'}
#
# Filename: 2.txt
# {'score': 0.42593061923980713, 'start': 4794, 'end': 4810, 'answer': 'not set in stone'}
#
# Filename: 4.txt
# {'score': 0.8636280298233032, 'start': 7747, 'end': 7766, 'answer': 'having no operation'}
#
# Filename: 11.txt
# {'score': 0.524783194065094, 'start': 3267, 'end': 3291, 'answer': 'it is the most authentic'}
#
# Filename: 15.txt
# {'score': 0.9440940618515015, 'start': 6145, 'end': 6162, 'answer': 'flipping the coin'}
#
# Filename: 10.txt
# {'score': 0.027786951512098312, 'start': 5151, 'end': 5185, 'answer': 'We will do whatever you want to do'}
#
# Filename: 20.txt
# {'score': 0.07847028225660324, 'start': 1220, 'end': 1283, 'answer': "to see people who don't have an operation how they cope with it"}
#
# Filename: 0.txt
# {'score': 0.6022684574127197, 'start': 1320, 'end': 1325, 'answer': 'trial'}
#
# Filename: 14.txt
# {'score': 0.8128585815429688, 'start': 4428, 'end': 4449, 'answer': 'into the non-surgical'}
#
# Filename: 18.txt
# {'score': 0.1279929131269455, 'start': 8279, 'end': 8311, 'answer': 'If you are randomised to surgery'}
#
# Filename: 29.txt
# {'score': 0.5226444602012634, 'start': 10329, 'end': 10345, 'answer': 'not an operation'}
#
# Filename: 27.txt
# {'score': 0.029297607019543648, 'start': 10827, 'end': 10881, 'answer': 'Maybe between patients he will nip back in and see you'}
#
# Filename: 21.txt
# {'score': 0.6856499910354614, 'start': 3639, 'end': 3661, 'answer': 'control approved trial'}
#
# Filename: 23.txt
# {'score': 0.05153163895010948, 'start': 1276, 'end': 1327, 'answer': 'to leave things alone, give you some dietary advice'}
#
# Filename: 25.txt
# {'score': 0.6239723563194275, 'start': 1911, 'end': 1929, 'answer': 'randomly allocated'}
#
# Filename: 3.txt
# {'score': 0.4296501874923706, 'start': 3801, 'end': 3820, 'answer': 'no treatment at all'}
#
# Filename: 19.txt
# {'score': 0.8375257253646851, 'start': 4950, 'end': 4985, 'answer': 'surgery straightaway and happy days'}
#
# Filename: 8.txt
# {'score': 0.5127856135368347, 'start': 8040, 'end': 8066, 'answer': 'quality life questionnaire'}
#
# Filename: 5.txt
# {'score': 0.5733681917190552, 'start': 7228, 'end': 7246, 'answer': 'to receive surgery'}
#
# Filename: 26.txt
# {'score': 0.20676164329051971, 'start': 628, 'end': 651, 'answer': 'medical management side'}
#
# Filename: 12.txt
# {'score': 0.5777550339698792, 'start': 6451, 'end': 6468, 'answer': 'treatment pathway'}
#
# Filename: 1.txt
# {'score': 0.2211475968360901, 'start': 5188, 'end': 5203, 'answer': "watch and wait'"}
#
# Filename: 24.txt
# {'score': 0.3236314058303833, 'start': 6361, 'end': 6408, 'answer': 'the decision as to whether you get an operation'}
#
# Filename: 7.txt
# {'score': 0.04324403032660484, 'start': 5545, 'end': 5553, 'answer': 'the band'}
#
# Filename: 17.txt
# {'score': 0.0577346570789814, 'start': 5406, 'end': 5432, 'answer': 'removal of the gallbladder'}
#
# Filename: 22.txt
# {'score': 0.10119597613811493, 'start': 15340, 'end': 15355, 'answer': 'when I get back'}
#
# Filename: 16.txt
# {'score': 0.01506124623119831, 'start': 3868, 'end': 3878, 'answer': 'two groups'}

# %%
import os
directory = '/content/test/'

for filename in os.listdir(directory):
  with open(directory + filename) as infile:
    try:

      next(infile)

      data=infile.read().replace('\n', '')
      print('\nFilename: ' + filename)
      print(nlp({
    'question': 'Are there pros and cons to each?',
    'context': data
}))
      
    except:
        print(filename + ' is throwing an error')




'''closest ever is     'question': 'Are there any advantages or disadvantages?', for now
and maybe 'What are the advantages or disadvantages of each?'''
# Out:
# Filename: 6.txt
# {'score': 0.06233702972531319, 'start': 4992, 'end': 5021, 'answer': "there's pros and cons of each"}
#
# Filename: 30.txt
# {'score': 0.2511036992073059, 'start': 1912, 'end': 1935, 'answer': 'two ways of managing it'}
#
# Filename: 9.txt
# {'score': 0.27773940563201904, 'start': 1826, 'end': 1854, 'answer': 'advantages and disadvantages'}
#
# Filename: 28.txt
# {'score': 0.018683429807424545, 'start': 2365, 'end': 2383, 'answer': '3, 6 and 12 months'}
#
# Filename: 13.txt
# {'score': 0.00466294726356864, 'start': 3850, 'end': 3899, 'answer': 'Contribution to the study is completely voluntary'}
#
# Filename: 2.txt
# {'score': 0.4114638864994049, 'start': 1226, 'end': 1257, 'answer': 'There are pros and cons to each'}
#
# Filename: 4.txt
# {'score': 0.059208206832408905, 'start': 3895, 'end': 3957, 'answer': 'every operation has complications and risks associated with it'}
#
# Filename: 11.txt
# {'score': 0.020970996469259262, 'start': 7978, 'end': 8014, 'answer': "we'll --P - You put it in the system"}
#
# Filename: 15.txt
# {'score': 0.14622549712657928, 'start': 10284, 'end': 10307, 'answer': "I'd co-operate with any"}
#
# Filename: 10.txt
# {'score': 0.020723091438412666, 'start': 5737, 'end': 5813, 'answer': 'Your participation is completely voluntary, and you can withdraw at any time'}
#
# Filename: 20.txt
# {'score': 0.025449462234973907, 'start': 1220, 'end': 1283, 'answer': "to see people who don't have an operation how they cope with it"}
#
# Filename: 0.txt
# {'score': 0.10958562791347504, 'start': 14911, 'end': 14970, 'answer': 'You may be contacted in the future for long term follow ups'}
#
# Filename: 14.txt
# {'score': 0.1259509027004242, 'start': 1179, 'end': 1224, 'answer': 'The majority of the patients have no symptoms'}
#
# Filename: 18.txt
# {'score': 0.007721784058958292, 'start': 5215, 'end': 5256, 'answer': 'they are there for the rest of their life'}
#
# Filename: 29.txt
# {'score': 0.14439450204372406, 'start': 13036, 'end': 13109, 'answer': 'there are some people who are clear cut, definitely need their operation.'}
#
# Filename: 27.txt
# {'score': 0.1427500993013382, 'start': 10477, 'end': 10518, 'answer': 'every ethical bone in my body is twanging'}
#
# Filename: 21.txt
# {'score': 0.006795018445700407, 'start': 7500, 'end': 7527, 'answer': 'we can do the randomisation'}
#
# Filename: 23.txt
# {'score': 0.4601629674434662, 'start': 1410, 'end': 1438, 'answer': 'advantages and disadvantages'}
#
# Filename: 25.txt
# {'score': 0.07068394124507904, 'start': 12997, 'end': 13037, 'answer': 'We have had ... just for varying reasons'}
#
# Filename: 3.txt
# {'score': 0.003853514092043042, 'start': 5524, 'end': 5592, 'answer': 'There are some complications attached with gallstones, you are right'}
#
# Filename: 19.txt
# {'score': 0.04838315770030022, 'start': 4762, 'end': 4820, 'answer': 'a constant or regular contact from the research trial unit'}
#
# Filename: 8.txt
# {'score': 0.14431272447109222, 'start': 3158, 'end': 3203, 'answer': "obviously there's pros and cons of doing each"}
#
# Filename: 5.txt
# {'score': 0.009892209433019161, 'start': 1966, 'end': 2002, 'answer': 'disadvantages and advantages of both'}
#
# Filename: 26.txt
# {'score': 0.03161586448550224, 'start': 556, 'end': 593, 'answer': "you've gone through the pros and cons"}
#
# Filename: 12.txt
# {'score': 0.13624835014343262, 'start': 1843, 'end': 1877, 'answer': 'Pains across my stomach and chest.'}
#
# Filename: 1.txt
# {'score': 0.005438740830868483, 'start': 2290, 'end': 2355, 'answer': 'monitor your diet and give you painkillers to try and help things'}
#
# Filename: 24.txt
# {'score': 0.3040805459022522, 'start': 1644, 'end': 1669, 'answer': 'P - No, it comes and goes'}
#
# Filename: 7.txt
# {'score': 0.05869175121188164, 'start': 1089, 'end': 1131, 'answer': "there's nothing dangerous going on with it"}
#
# Filename: 17.txt
# {'score': 0.004305950365960598, 'start': 11120, 'end': 11139, 'answer': 'on the waiting list'}
#
# Filename: 22.txt
# {'score': 0.0642324835062027, 'start': 9861, 'end': 9871, 'answer': 'inaudible)'}
#
# Filename: 16.txt
# {'score': 0.01336299255490303, 'start': 1331, 'end': 1406, 'answer': 'As with nearly one in three people afterwards, they have long-term symptoms'}
# "closest ever is     'question': 'Are there any advantages or disadvantages?', for now\nand maybe 'What are the advantages or disadvantages of each?"

# %%
import os


directory = '/content/test/'

for filename in os.listdir(directory):
  with open(directory + filename) as infile:
    try:

      next(infile)

      data=infile.read().replace('\n', '')
      print('\nFilename: ' + filename)
      print(nlp({
    'question': 'Are the risks known?',
    'context': data
}))

    except:
        print(filename + ' is throwing an error')
# Out:
# Filename: 29.txt
# {'score': 0.05910508707165718, 'start': 7329, 'end': 7350, 'answer': 'classically gallstone'}
#
# Filename: 10.txt
# {'score': 0.003850723383948207, 'start': 5033, 'end': 5077, 'answer': "The painkillers didn't work very well at all"}
#
# Filename: 26.txt
# {'score': 0.018170222640037537, 'start': 2329, 'end': 2357, 'answer': 'those are the mandatory ones'}
#
# Filename: 15.txt
# {'score': 0.49451756477355957, 'start': 12037, 'end': 12100, 'answer': 'whether you get to be in the medical management or the surgical'}
#
# Filename: 21.txt
# {'score': 0.022403839975595474, 'start': 1297, 'end': 1318, 'answer': "Not that I've noticed"}
#
# Filename: 25.txt
# {'score': 0.10989824682474136, 'start': 2901, 'end': 2932, 'answer': 'there are risks to that as well'}
#
# Filename: 24.txt
# {'score': 0.31555718183517456, 'start': 4467, 'end': 4486, 'answer': 'the risks are small'}
#
# Filename: 8.txt
# {'score': 0.2669525146484375, 'start': 8692, 'end': 8738, 'answer': "I've expired, never mind perspired but expired"}
#
# Filename: 19.txt
# {'score': 0.18996460735797882, 'start': 4925, 'end': 4985, 'answer': 'you may be randomised to surgery straightaway and happy days'}
#
# Filename: 3.txt
# {'score': 0.11981931328773499, 'start': 1806, 'end': 1875, 'answer': 'Every operation you have has risks and complications attached with it'}
#
# Filename: 6.txt
# {'score': 0.2653932273387909, 'start': 4709, 'end': 4759, 'answer': "all of these operations aren't without their risks"}
#
# Filename: 5.txt
# {'score': 0.07001660764217377, 'start': 2731, 'end': 2767, 'answer': 'the advantage is it gets rid of them'}
#
# Filename: 22.txt
# {'score': 0.1927676945924759, 'start': 8021, 'end': 8060, 'answer': "you might get the answer you don't want"}
#
# Filename: 13.txt
# {'score': 0.045760031789541245, 'start': 7899, 'end': 7958, 'answer': 'just if you avoid anything fatty that you are already doing'}
#
# Filename: 23.txt
# {'score': 0.1579582244157791, 'start': 2113, 'end': 2124, 'answer': 'small risks'}
#
# Filename: 1.txt
# {'score': 0.31371963024139404, 'start': 6324, 'end': 6350, 'answer': 'it seems to have got worse'}
#
# Filename: 12.txt
# {'score': 0.1385796070098877, 'start': 5689, 'end': 5722, 'answer': "you don't undergo all these risks"}
#
# Filename: 14.txt
# {'score': 0.04506369307637215, 'start': 1179, 'end': 1224, 'answer': 'The majority of the patients have no symptoms'}
#
# Filename: 28.txt
# {'score': 0.05516168102622032, 'start': 3301, 'end': 3322, 'answer': 'nobody actually knows'}
#
# Filename: 27.txt
# {'score': 0.10597700625658035, 'start': 9295, 'end': 9337, 'answer': 'My life is not very exciting at the moment'}
#
# Filename: 9.txt
# {'score': 0.1494978666305542, 'start': 1816, 'end': 1862, 'answer': 'there are advantages and disadvantages of both'}
#
# Filename: 0.txt
# {'score': 0.16914105415344238, 'start': 8275, 'end': 8321, 'answer': 'both seem to have advantages and disadvantages'}
#
# Filename: 20.txt
# {'score': 0.05672390013933182, 'start': 1067, 'end': 1104, 'answer': 'the stones are quite a common problem'}
#
# Filename: 18.txt
# {'score': 0.364126056432724, 'start': 8892, 'end': 8923, 'answer': 'It will only take a few minutes'}
#
# Filename: 11.txt
# {'score': 0.07808273285627365, 'start': 2210, 'end': 2243, 'answer': 'The trial is completely voluntary'}
#
# Filename: 2.txt
# {'score': 0.30501997470855713, 'start': 2923, 'end': 2986, 'answer': 'We have never really known which is the best way to manage them'}
#
# Filename: 4.txt
# {'score': 0.12642747163772583, 'start': 7066, 'end': 7082, 'answer': 'it is quite rare'}
#
# Filename: 7.txt
# {'score': 0.2759248614311218, 'start': 1089, 'end': 1131, 'answer': "there's nothing dangerous going on with it"}
#
# Filename: 17.txt
# {'score': 0.5825421214103699, 'start': 4991, 'end': 5017, 'answer': 'infection, bleeding, scars'}
#
# Filename: 30.txt
# {'score': 0.030981440097093582, 'start': 3562, 'end': 3599, 'answer': "we haven't known what best way to do."}
#
# Filename: 16.txt
# {'score': 0.4725395739078522, 'start': 1223, 'end': 1246, 'answer': 'it still has some risks'}
