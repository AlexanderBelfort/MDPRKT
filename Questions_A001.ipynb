# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderBelfort/MDPRKT/blob/main/Questions_A001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing transformers is the first step.

# %%
# !pip install transformers

# %%
from transformers import pipeline
from transformers import AutoConfig, AutoModel

# %% [markdown]
# Use a **cased** model to **make a difference between english and English** and evaluate said model

# %%
model = AutoModel.from_pretrained('bert-base-cased')
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
# ...

# %%
nlp = pipeline('question-answering')

# %%
import os


directory = '/content/test/'

for filename in os.listdir(directory):
  with open(directory + filename) as infile:
    try:

      next(infile)

      data=infile.read().replace('\n', '')
      print('\nFilename: ' + filename)
      print(nlp({
    'question': 'What does the computer decide?',
    'context': data
}))

    except:
        print(filename + ' is throwing an error')


'''
some testing
from transformers import pipeline

qa_pipeline = pipeline(
    "question-answering",
    model="madlag/bert-base-uncased-squadv1-x2.44-f87.7-d26-hybrid-filled-v1",
    tokenizer="madlag/bert-base-uncased-squadv1-x2.44-f87.7-d26-hybrid-filled-v1"
)'''
# Out:
# Filename: 6.txt
# {'score': 0.4266800582408905, 'start': 6380, 'end': 6423, 'answer': "whether you're going to have the stones out"}
#
# Filename: 30.txt
# {'score': 0.28379008173942566, 'start': 8164, 'end': 8209, 'answer': 'randomised, my darling, to medical management'}
#
# Filename: 9.txt
# {'score': 0.40633878111839294, 'start': 2947, 'end': 3012, 'answer': 'whether to have an operation or whether to just keep an eye on it'}
#
# Filename: 28.txt
# {'score': 0.050219275057315826, 'start': 3438, 'end': 3450, 'answer': 'consent form'}
#
# Filename: 13.txt
# {'score': 0.11498253047466278, 'start': 7757, 'end': 7778, 'answer': 'give us your initials'}
#
# Filename: 2.txt
# {'score': 0.1330416202545166, 'start': 4159, 'end': 4205, 'answer': 'whether or not you are suffering with the pain'}
#
# Filename: 4.txt
# {'score': 0.2755652964115143, 'start': 12046, 'end': 12085, 'answer': 'you are allocated to medical management'}
#
# Filename: 11.txt
# ...

# %%
import os
directory = '/content/test/'

for filename in os.listdir(directory):
  with open(directory + filename) as infile:
    try:

      next(infile)

      data=infile.read().replace('\n', '')
      print('\nFilename: ' + filename)
      print(nlp({
    'question': 'What are you randomised for?',
    'context': data
}))

    except:
        print(filename + ' is throwing an error')
# Out:
# Filename: 6.txt
# {'score': 0.42546188831329346, 'start': 9993, 'end': 10008, 'answer': 'show gallstones'}
#
# Filename: 30.txt
# {'score': 0.813377320766449, 'start': 8191, 'end': 8209, 'answer': 'medical management'}
#
# Filename: 9.txt
# {'score': 0.8999626636505127, 'start': 7130, 'end': 7140, 'answer': 'no surgery'}
#
# Filename: 28.txt
# {'score': 0.8951448202133179, 'start': 1428, 'end': 1435, 'answer': 'surgery'}
#
# Filename: 13.txt
# {'score': 0.9406484365463257, 'start': 4072, 'end': 4079, 'answer': 'surgery'}
#
# Filename: 2.txt
# {'score': 0.42593061923980713, 'start': 4794, 'end': 4810, 'answer': 'not set in stone'}
#
# Filename: 4.txt
# {'score': 0.8636280298233032, 'start': 7747, 'end': 7766, 'answer': 'having no operation'}
#
# Filename: 11.txt
# {'score': 0.524783194065094, 'start': 3267, 'end': 3291, 'answer': 'it is the most authentic'}
#
# Filename: 15.txt
# {'score': 0.9440940618515015, 'start': 6145, 'end': 6162, 'answer': 'flipping the coin'}
#
# ...

# %%
import os
directory = '/content/test/'

for filename in os.listdir(directory):
  with open(directory + filename) as infile:
    try:

      next(infile)

      data=infile.read().replace('\n', '')
      print('\nFilename: ' + filename)
      print(nlp({
    'question': 'What is your treatment preference?',
    'context': data
}))

    except:
        print(filename + ' is throwing an error')
# Out:
# Filename: 6.txt
# {'score': 0.05104591324925423, 'start': 822, 'end': 832, 'answer': 'marvellous'}
#
# Filename: 30.txt
# {'score': 0.08723344653844833, 'start': 8164, 'end': 8209, 'answer': 'randomised, my darling, to medical management'}
#
# Filename: 9.txt
# {'score': 0.18563829362392426, 'start': 7115, 'end': 7140, 'answer': 'randomised for no surgery'}
#
# Filename: 28.txt
# {'score': 0.007190089672803879, 'start': 3277, 'end': 3322, 'answer': 'comparing that, because nobody actually knows'}
#
# Filename: 13.txt
# {'score': 0.4383528530597687, 'start': 5219, 'end': 5251, 'answer': 'your wishes are our top priority'}
#
# Filename: 2.txt
# {'score': 0.3884817361831665, 'start': 8484, 'end': 8496, 'answer': 'Not eligible'}
#
# Filename: 4.txt
# {'score': 0.881601870059967, 'start': 3572, 'end': 3579, 'answer': 'healthy'}
#
# Filename: 11.txt
# {'score': 0.008374394848942757, 'start': 1780, 'end': 1816, 'answer': 'an operation to remove the gallstone'}
#
# Filename: 15.txt
# ...
